# %% [markdown]
# ## Day 15 Regularization
# 30/Dec/2021 Thursday

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
x = np.linspace(0, 20, n)
noise = np.random.randn(n)
y = x**2 + 20*noise # relationship between y and x is quadratic
plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.scatter(x**2, y) # relationship between x_squared and y is linear
plt.show()

# %% [markdown]
# ### Sklearn

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
model = Ridge()
model.fit(X,y)
model.predict(X_test)
